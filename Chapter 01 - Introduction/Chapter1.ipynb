# %% [markdown]
# <a href="https://colab.research.google.com/github/smilven/Practical-Discrete-Mathematics/blob/master/Chapter%2001%20-%20Introduction/Chapter1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 1 - Introduction: Key Concepts, Notation, Set Theory, Relations, and Functions
#
# This notebook contains code accompanying Chapter 1 Introduction: Key Concepts, Notation, Set Theory, Relations, and Functions in *Practical Discrete Mathematics* by Ryan T. White and Archana Tikayat Ray
#
# ## Functions and Relations
#
# ### The `sort()` function

# %%
numbers = [3,0.92, 0.92, 1, 8, 5, 2, 9]
names = ['Wyatt', 'Brandon', 'Kumar', 'Eugene', 'Elise']

# Apply the sort() function to the lists
numbers.sort()
names.sort()

# Display the output
print(numbers)
print(names)
# Out:
# [0.92, 0.92, 1, 2, 3, 5, 8, 9]
# ['Brandon', 'Elise', 'Eugene', 'Kumar', 'Wyatt']

# %% [markdown]
# ### The `shuffle()` function

# %%
import random

# Set a random seed so the code is reproducible
random.seed(1)

# Run the random.shuffle() function 5 times and display the outputs
for i in range(0,5):
    numbers = [3, 1, 4, 12, 8, 5, 2, 9]
    random.shuffle(numbers)
    print(numbers)
# Out:
# [12, 2, 1, 5, 9, 3, 8, 4]
# [4, 2, 8, 3, 1, 12, 5, 9]
# [4, 5, 1, 9, 3, 8, 12, 2]
# [9, 12, 2, 8, 5, 3, 4, 1]
# [9, 8, 4, 3, 12, 1, 5, 2]

# %%
# Define two sets of numbers
set1 = {1, 2, 3, 4, 5}
set2 = {4, 5, 6, 7, 8}

# Find the union of the two sets
union_set = set1.union(set2)

# Print the result
print("Set 1:", set1)
print("Set 2:", set2)
print("Union of Set 1 and Set 2:", union_set)
# Out:
# Set 1: {1, 2, 3, 4, 5}
# Set 2: {4, 5, 6, 7, 8}
# Union of Set 1 and Set 2: {1, 2, 3, 4, 5, 6, 7, 8}

# %%
import random

# Function to create a set of random numbers
def create_random_set(size, lower_bound, upper_bound):
    return set(random.randint(lower_bound, upper_bound) for _ in range(size))

# Create two sets of random numbers
set1 = create_random_set(10, 1, 20)
set2 = create_random_set(10, 1, 20)

# Find the common numbers in the two sets
common_numbers = set1.intersection(set2)

# Print the results
print("Set 1:", set1)
print("Set 2:", set2)
print("Common numbers in Set 1 and Set 2:", common_numbers)
# Out:
# Set 1: {1, 8, 10, 12, 15, 16, 18}
# Set 2: {4, 6, 10, 11, 14, 17, 18}
# Common numbers in Set 1 and Set 2: {10, 18}

# %%
import random

def shuffle_name(name):
    # Split the name into characters
    name_chars = list(name)
    # Shuffle the characters
    random.shuffle(name_chars)
    # Join the characters back into a string
    shuffled_name = ''.join(name_chars)
    return shuffled_name

# Example name
name = "Mii Si Heng"
shuffled_name = shuffle_name(name)

print("Original name:", name)
print("Shuffled name:", shuffled_name)
# Out:
# Original name: Mii Si Heng
# Shuffled name: iMii nHeS g

# %%
import pandas as pd

# URL of the Wikipedia page
url = "https://en.wikipedia.org/wiki/Frieren"

# Extract all tables from the webpage
tables = pd.read_html(url)

# Display the first table (you can change the index to display other tables)
print(tables)
# Out:
# [                                                    0  \
# 0                       Frieren: Beyond Journey's End
# 1   First tankōbon volume cover, featuring (from l...
# 2                          葬送のフリーレン (Sōsō no Furīren)
# 3                                               Genre
# 4                                               Manga
# 5                                          Written by
# 6                                      Illustrated by
# 7                                        Published by
# 8                                   English publisher
# 9                                             Imprint
# 19  2024           4th Astra TV Awards                    Best Anime Series
#
#                         Recipient      Result   Ref.
# 0   Frieren: Beyond Journey's End   4th place  [101]
# 1              "Yūsha" by Yoasobi  16th place  [102]
# 2              "Yūsha" by Yoasobi   Nominated  [103]
# 3    Milet for "Anytime Anywhere"   Nominated  [104]
# 4   Frieren: Beyond Journey's End   2nd place  [105]
# 5   Frieren: Beyond Journey's End   8th place  [106]
# 6                         Yoasobi         Won  [107]
# 7   Frieren: Beyond Journey's End         Won  [108]
# 8   Frieren: Beyond Journey's End   4th place  [109]
# 9                         Frieren   7th place  [109]
# 10             "Yūsha" by Yoasobi   6th place  [109]
# 11    "Anytime Anywhere" by Milet   9th place  [109]
# 12           "Sunny" by Yorushika  10th place  [109]
# 13                Atsumi Tanezaki         Won  [109]
# 14  Frieren: Beyond Journey's End         Won  [110]
# 15  Frieren: Beyond Journey's End         Won  [110]
# 16    "Anytime Anywhere" by Milet         Won  [110]
# 17  Frieren: Beyond Journey's End   Nominated  [111]
# 18             "Yūsha" by Yoasobi   Nominated  [111]
# 19  Frieren: Beyond Journey's End     Pending  [112]  ,   vteFrieren: Beyond Journey's End by Kanehito Yamada and Tsukasa Abe  \
# 0  Characters Frieren Chapters Episodes "Yūsha" "...
#
#   vteFrieren: Beyond Journey's End by Kanehito Yamada and Tsukasa Abe.1
# 0  Characters Frieren Chapters Episodes "Yūsha" "...                     ,                             Links to related articles  \
# 0   vteSeries currently running in Weekly Shōnen S...
# 1   vteSeries currently running in Weekly Shōnen S...
# 2   Magic Kaito Case Closed Major 2nd Ad Astra per...
# 3                              Website: websunday.net
# 4               vteWeekly Shōnen Sunday: 2020–present
# 5                                                2020
# 6                                                2021
# 7                                                2022
# 8                                                2023
# 9                                                2024
# 10  1959–19691970–19791980–19891990–19992000–20092...
# 11                                    vteManga Taishō
# 12                                              2000s
# 13                                              2010s
# 14                                              2020s
# 15                     vteTezuka Osamu Cultural Prize
# 16                                        Grand Prize
# 17                                              1990s
# 18                                              2000s
# 19                                              2010s
# 20                                              2020s
# 21                                     Special  Award
# 22                                              1990s
# 23                                              2000s
# 24                                              2010s
# 25                                              2020s
# 26                              Award for  Excellence
# 27                                    Creative  Award
# 28                                  New Artist  Prize
# 29                                 Short Story  Award
# 30                  vteShogakukan Manga Award (2023–)
# 31                                               2023
# 32  Categories (until 2022):GeneralShōnenShōjoChil...
# 33                   vteKodansha Manga Award – Shōnen
# 34                                              1970s
# 35                                              1980s
# 36                                              1990s
# 37                                              2000s
# 38                                              2010s
# 39                                              2020s
# 40                      vteMadhouse television series
# 41                                          Pre-2000s
# 42                                          2000–2005
# 43                                          2006–2010
# 44                                              2010s
# 45                                              2020s
# 46                                           Category
#
#                           Links to related articles.1
# 0   vteSeries currently running in Weekly Shōnen S...
# 1   vteSeries currently running in Weekly Shōnen S...
# 2   Magic Kaito Case Closed Major 2nd Ad Astra per...
# 3                              Website: websunday.net
# 4               vteWeekly Shōnen Sunday: 2020–present
# 5   Frieren: Bryond Journey's End Itoyan Goto Naki...
# 6   Kakeau Tsukihi Shibuya Near Family Shiroyama t...
# 7   Red Blue Last Karte I Wanna Do Bad Things with...
# 8   Super String: Marco Polo's Travel to the Multi...
# 9                                     Kai-hen Wizards
# 10  1959–19691970–19791980–19891990–19992000–20092...
